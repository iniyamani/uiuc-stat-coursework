# %% [markdown]
# # STAT 207 Homework 10 [25 points]
#
# ## Feature Selection for Linear Models

# %% [markdown]
# Due: Monday, April 27, end of day (11:59 pm CT)
#
# Late submissions accepted until Tuesday, April 28 at noon
#
# <hr>

# %% [markdown]
# ## Imports
#
# Run the following code cell to import the necessary packages into the file.  You may import additional packages, as needed for this assignment.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import statsmodels.formula.api as smf

# %% [markdown]
# ## The Data
#
# A famous study called "SUPPORT" (Study to Understand Prognoses Preferences Outcomes and Risks of Treatment) was conducted to determine what factors affected or predicted outcomes, including how long a patient remained in the hospital.
#
# We will use a random sample of 580 seriously ill hospitalized patients from the SUPPORT study, with the following variables:
#
# - **`Days`**: day to death or hospital discharge
# - **`Age`**: age on day of hospital admission
# - **`Sex`**: female or male
# - **`Comorbidity`**: patient diagnosed with more than one chronic disease
# - **`EdYears`**: years of education
# - **`Education`**: education level: high or low
# - **`Income`**: income level: high or low
# - **`Charges`**: hospital charges, in dollars
# - **`Care`**: level of care required: high or low
# - **`Race`**: Non-white or white
# - **`Pressure`**: Blood pressure, in mmHg
# - **`Blood`**: white blood cell count, in gm/dL
# - **`Rate`**: heart rate, in bpm
#
# Run the code in the cell below to read in the cleaned data and separate the data into a training and test set for this document.  The data is saved as `df` with this code, and then separated into a `df_train` and `df_test` for later analysis.

# %%
df = pd.read_csv('hospital.csv')
df_train, df_test = train_test_split(df, test_size = 0.20, random_state = 9876)

# %% [markdown]
# ## 1. Research Purpose [0 points]
#
# Question 1 does not require any analysis.
#
# I'd suggest turning to Q1 on Gradescope here to answer the conceptual questions.

# %% [markdown]
# ## 2. Fitting our Full Model [1 point]
#
# For the purposes of this question, we want to be sure that we only include variables that could be determined or anticipated upon admittance to the hospital, so that our model can be applied to new patients.
#
# **a)** Fit a linear model to the training data to predict the length of the hospital stay (**`Days`**) with the following predictor variables: `Age`, `Sex`, `Comorbidity`, `EdYears`, `Education`, `Income`, `Care`, `Race`, `Pressure`, `Blood`, and `Rate`.  Print a summary of this linear model.

# %%
model = smf.ols("Days~ Age+Sex+Comorbidity+EdYears+Education+Income+Care+Race+Pressure+Blood+Rate", data = df_train).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   Days   R-squared:                       0.150
# Model:                            OLS   Adj. R-squared:                  0.129
# Method:                 Least Squares   F-statistic:                     7.230
# Date:                Tue, 28 Apr 2026   Prob (F-statistic):           2.13e-11
# Time:                        01:18:17   Log-Likelihood:                -2042.3
# No. Observations:                 464   AIC:                             4109.
# Df Residuals:                     452   BIC:                             4158.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %% [markdown]
# **b)** I'd suggest turning to Q2 on Gradescope here.
#
# I don't anticipate a need to perform any more calculations or analyses for this problem.  This space is available for any optional calculations or analyses that you'd like.

# %% [markdown]
# ## 3. Metrics for Model Fit [0 points]
#
# I'd suggest turning to Q3 on Gradescope here to answer the conceptual questions.
#
# Question 3 does not require any analysis.  This space is available for any optional calculations or analyses that you'd like.

# %% [markdown]
# ## 4. Selecting a Parsimonious Model [3 points]
#
# **a)** We'll perform model selection using backwards elimination starting from the full model fit in Question 2 and using the $R^2_{\text{adj}}$ as our metric using our training data.  Be sure to show your work.  That is, don't delete any models that you fit.  Add as many code cells below as you need.

# %%
model = smf.ols('Days ~ Age + Sex + Comorbidity + EdYears + Education + Income + Care + Race + Pressure + Blood + Rate', data = df_train).fit()
model.rsquared_adj
# Out:
# np.float64(0.1289374762917086)

# %%
model1 = smf.ols('Days ~ Sex + Comorbidity + EdYears + Education + Income + Care + Race + Pressure + Blood + Rate', data = df_train).fit()
model1.rsquared_adj
# Out:
# np.float64(0.12776010131275162)

# %%
model2 = smf.ols('Days ~ Age + Comorbidity + EdYears + Education + Income + Care + Race + Pressure + Blood + Rate', data = df_train).fit()
model2.rsquared_adj
# Out:
# np.float64(0.12791491513245434)

# %%
model3 = smf.ols('Days ~ Age + Sex  + EdYears + Education + Income + Care + Race + Pressure + Blood + Rate', data = df_train).fit()
model3.rsquared_adj
# Out:
# np.float64(0.12998928877883442)

# %%
model4 = smf.ols('Days ~ Age + Sex + Comorbidity + Education + Income + Care + Race + Pressure + Blood + Rate', data = df_train).fit()
model4.rsquared_adj
# Out:
# np.float64(0.12889643575021414)

# %%
model5 = smf.ols('Days ~ Age + Sex + Comorbidity + EdYears + Income + Care + Race + Pressure + Blood + Rate', data = df_train).fit()
model5.rsquared_adj
# Out:
# np.float64(0.13085492642170327)

# %%
model6 = smf.ols('Days ~ Age + Sex + Comorbidity + EdYears + Education + Care + Race + Pressure + Blood + Rate', data = df_train).fit()
model6.rsquared_adj
# Out:
# np.float64(0.1297856557760172)

# %%
model7 = smf.ols('Days ~ Age + Sex + Comorbidity + EdYears + Education + Income + Race + Pressure + Blood + Rate', data = df_train).fit()
model7.rsquared_adj
# Out:
# np.float64(0.06967923272540044)

# %%
model8 = smf.ols('Days ~ Age + Sex + Comorbidity + EdYears + Education + Income + Care + Pressure + Blood + Rate', data = df_train).fit()
model8.rsquared_adj
# Out:
# np.float64(0.12680769333246678)

# %%
model9 = smf.ols('Days ~ Age + Sex + Comorbidity + EdYears + Education + Income + Care + Race + Blood + Rate', data = df_train).fit()
model9.rsquared_adj
# Out:
# np.float64(0.10835918498315111)

# %%
model10 = smf.ols('Days ~ Age + Sex + Comorbidity + EdYears + Education + Income + Care + Race + Pressure + Rate', data = df_train).fit()
model10.rsquared_adj
# Out:
# np.float64(0.13053934945893897)

# %%
model11 = smf.ols('Days ~ Age + Sex + Comorbidity + EdYears + Education + Income + Care + Race + Pressure + Blood', data = df_train).fit()
model11.rsquared_adj
# Out:
# np.float64(0.12159121668357964)

# %%
model12 = smf.ols('Days ~ Sex + Comorbidity + EdYears + Income + Care + Race + Pressure + Blood + Rate', data = df_train).fit()
model12.rsquared_adj
# Out:
# np.float64(0.12962152737179466)

# %%
model13 = smf.ols('Days ~ Age + Comorbidity + EdYears + Income + Care + Race + Pressure + Blood + Rate', data = df_train).fit()
model13.rsquared_adj
# Out:
# np.float64(0.12982708127311382)

# %%
model14 = smf.ols('Days ~ Age + Sex + EdYears + Income + Care + Race + Pressure + Blood + Rate', data = df_train).fit()
model14.rsquared_adj
# Out:
# np.float64(0.1319033456064036)

# %%
model15 = smf.ols('Days ~ Age + Sex + Comorbidity + Income + Care + Race + Pressure + Blood + Rate', data = df_train).fit()
model15.rsquared_adj
# Out:
# np.float64(0.12876100015069003)

# %%
model16 = smf.ols('Days ~ Age + Sex + Comorbidity + EdYears + Care + Race + Pressure + Blood + Rate', data = df_train).fit()
model16.rsquared_adj
# Out:
# np.float64(0.13169976859509902)

# %%
model17 = smf.ols('Days ~ Age + Sex + Comorbidity + EdYears + Income + Race + Pressure + Blood + Rate', data = df_train).fit()
model17.rsquared_adj
# Out:
# np.float64(0.07169042487409483)

# %%
model18 = smf.ols('Days ~ Age + Sex + Comorbidity + EdYears + Income + Care + Pressure + Blood + Rate', data = df_train).fit()
model18.rsquared_adj
# Out:
# np.float64(0.12864982359692545)

# %%
model19 = smf.ols('Days ~ Age + Sex + Comorbidity + EdYears + Income + Care + Race + Blood + Rate', data = df_train).fit()
model19.rsquared_adj
# Out:
# np.float64(0.11030535245788053)

# %%
model20 = smf.ols('Days ~ Age + Sex + Comorbidity + EdYears + Income + Care + Race + Pressure + Rate', data = df_train).fit()
model20.rsquared_adj
# Out:
# np.float64(0.1324505968924028)

# %%
model21 = smf.ols('Days ~ Age + Sex + Comorbidity + EdYears + Income + Care + Race + Pressure + Blood', data = df_train).fit()
model21.rsquared_adj
# Out:
# np.float64(0.12351093259159662)

# %%
model22 = smf.ols('Days ~ Sex + Comorbidity + EdYears + Income + Care + Race + Pressure + Rate', data = df_train).fit()
model22.rsquared_adj
# Out:
# np.float64(0.1313619088761112)

# %%
model23 = smf.ols('Days ~ Age + Comorbidity + EdYears + Income + Care + Race + Pressure + Rate', data = df_train).fit()
model23.rsquared_adj
# Out:
# np.float64(0.13120041742899347)

# %%
model24 = smf.ols('Days ~ Age + Sex + EdYears + Income + Care + Race + Pressure + Rate', data = df_train).fit()
model24.rsquared_adj
# Out:
# np.float64(0.13330384189659417)

# %%
model25 = smf.ols('Days ~ Age + Sex + Comorbidity + Income + Care + Race + Pressure + Rate', data = df_train).fit()
model25.rsquared_adj
# Out:
# np.float64(0.13021404280763504)

# %%
model26 = smf.ols('Days ~ Age + Sex + Comorbidity + EdYears + Income + Race + Pressure + Rate', data = df_train).fit()
model26.rsquared_adj
# Out:
# np.float64(0.07207941954353869)

# %%
model27 = smf.ols('Days ~ Age + Sex + Comorbidity + EdYears + Income + Care + Pressure + Rate', data = df_train).fit()
model27.rsquared_adj
# Out:
# np.float64(0.13011950313962461)

# %%
model28 = smf.ols('Days ~ Age + Sex + Comorbidity + EdYears + Income + Care + Race + Rate', data = df_train).fit()
model28.rsquared_adj
# Out:
# np.float64(0.1116411690008764)

# %%
model29 = smf.ols('Days ~ Age + Sex + Comorbidity + EdYears + Income + Care + Race + Pressure', data = df_train).fit()
model29.rsquared_adj
# Out:
# np.float64(0.12463896132070507)

# %%
model30 = smf.ols('Days ~ Sex + Comorbidity + EdYears + Care + Race + Pressure + Rate', data = df_train).fit()
model30.rsquared_adj
# Out:
# np.float64(0.13228259651502539)

# %%
model31 = smf.ols('Days ~ Age + Comorbidity + EdYears + Care + Race + Pressure + Rate', data = df_train).fit()
model31.rsquared_adj
# Out:
# np.float64(0.132463081412166)

# %%
model32 = smf.ols('Days ~ Age + Sex + EdYears + Care + Race + Pressure + Rate', data = df_train).fit()
model32.rsquared_adj
# Out:
# np.float64(0.13402570920886225)

# %%
model33 = smf.ols('Days ~ Age + Sex + Comorbidity + Care + Race + Pressure + Rate', data = df_train).fit()
model33.rsquared_adj
# Out:
# np.float64(0.13206643967097986)

# %%
model34 = smf.ols('Days ~ Age + Sex + Comorbidity + EdYears + Race + Pressure + Rate', data = df_train).fit()
model34.rsquared_adj
# Out:
# np.float64(0.07275501526291583)

# %%
model35 = smf.ols('Days ~ Age + Sex + Comorbidity + EdYears + Care + Pressure + Rate', data = df_train).fit()
model35.rsquared_adj
# Out:
# np.float64(0.13048250575518427)

# %%
model36 = smf.ols('Days ~ Age + Sex + Comorbidity + EdYears + Care + Race + Rate', data = df_train).fit()
model36.rsquared_adj
# Out:
# np.float64(0.11267264853145353)

# %%
model37 = smf.ols('Days ~ Age + Sex + Comorbidity + EdYears + Care + Race + Pressure', data = df_train).fit()
model37.rsquared_adj
# Out:
# np.float64(0.12579139979463094)

# %%
model38 = smf.ols('Days ~  Sex + EdYears + Care + Race + Pressure + Rate', data = df_train).fit()
model38.rsquared_adj
# Out:
# np.float64(0.13276582399548575)

# %%
model39 = smf.ols('Days ~ Age + EdYears + Care + Race + Pressure + Rate', data = df_train).fit()
model39.rsquared_adj
# Out:
# np.float64(0.13291624358124488)

# %%
model40 = smf.ols('Days ~ Age + Sex + Care + Race + Pressure + Rate', data = df_train).fit()
model40.rsquared_adj
# Out:
# np.float64(0.13302234791793466)

# %%
model41 = smf.ols('Days ~ Age + Sex + EdYears + Race + Pressure + Rate', data = df_train).fit()
model41.rsquared_adj
# Out:
# np.float64(0.06496144885817978)

# %%
model42 = smf.ols('Days ~ Age + Sex + EdYears + Care + Pressure + Rate', data = df_train).fit()
model42.rsquared_adj
# Out:
# np.float64(0.1311699766104929)

# %%
model43 = smf.ols('Days ~ Age + Sex + EdYears + Care + Race + Rate', data = df_train).fit()
model43.rsquared_adj
# Out:
# np.float64(0.11324299483545086)

# %%
model44 = smf.ols('Days ~ Age + Sex + EdYears + Care + Race + Pressure', data = df_train).fit()
model44.rsquared_adj
# Out:
# np.float64(0.1267820133544637)

# %%
final_model = smf.ols('Days ~ Age + Sex + EdYears + Care + Race + Pressure + Rate', data = df_train).fit()
final_model.rsquared_adj
# Out:
# np.float64(0.13402570920886225)

# %% [markdown]
# **b)** I'd suggest turning to Q4 on Gradescope here.
#
# I don't anticipate a need to perform any more calculations or analyses for this problem.  This space is available for any optional calculations or analyses that you'd like.

# %% [markdown]
# ## 5. Measuring our Test Data [0 points]
#
# For this question, you'll calculate an appropriate measure of model fit through an $R^2$ (either unadjusted or adjusted $R^2$) on our test data based on our model selected and fit to our training data in Question 4.  You do not need to fit a new model for this question.
#
# You will need to perform additional calculations or analyses for this problem.  This space is available for those calculations, although there are no points associated with the code.  You will enter the results of your calculation on Q5 on Gradescope.

# %% [markdown]
# ## 6. AI Acknowledgement
#
# Our course policy is that you should write all of your own interpretations and other narrative answers (phrases or sentences) yourself without the assistance of AI.  You may use AI to help guide your code, although you should write all of your own code yourself (not copy-paste from another source) and you should cite your use of AI.  I would encourage you to try to generate any necessary code yourself first using course resources and using AI as a debugging tool if/when you reach an error that you can't figure out or to help you perform any coding tasks that are more advanced than we've demonstrated during class (intended only for projects).
#
# Did you use AI on this assignment?  Did you use other resources outside of our course-provided resources on this assignment?

# %% [markdown]
# no

# %% [markdown]
# If you used AI or other resources, answer the following questions to cite your usage.
#
# - Which AI and/or resources did you use (including links, if appropriate)?
# - What prompts did you ask it?
# - How did you integrate the responses into your assignment?  Specifically, which questions or parts are associated with this usage?
#
# Note: answering these three questions are enough for our course but may not be enough for a different course or context.

# %% [markdown]
# Remember to keep all your cells and hit the save icon above periodically to checkpoint (save) your results on your local computer. Once you are satisified with your results restart the kernel and run all (Kernel -> Restart & Run All). **Make sure nothing has changed**. Checkpoint and exit (File -> Save and Checkpoint + File -> Close and Halt). Follow the instructions on the Homework 10 Canvas Assignment to submit your notebook to GitHub.
